# %%
# !pip install cufflinks
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cufflinks in c:\users\lenovo\appdata\roaming\python\python313\site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from cufflinks) (2.4.2)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from cufflinks) (2.3.3)
# Requirement already satisfied: plotly>=4.1.1 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from cufflinks) (5.13.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from cufflinks) (1.17.0)
# Requirement already satisfied: colorlover>=0.2.1 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in c:\programdata\anaconda3\lib\site-packages (from cufflinks) (80.9.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from cufflinks) (9.10.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\programdata\anaconda3\lib\site-packages (from cufflinks) (8.1.7)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->cufflinks) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->cufflinks) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->cufflinks) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->cufflinks) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->cufflinks) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->cufflinks) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->cufflinks) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.5.3)
# Requirement already satisfied: comm>=0.1.3 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.15)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from jedi>=0.18.1->ipython>=5.3.0->cufflinks) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from pandas>=0.19.2->cufflinks) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from pandas>=0.19.2->cufflinks) (2025.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from plotly>=4.1.1->cufflinks) (9.1.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (0.2.3)

# %%
pip install plotly==5.13.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: plotly==5.13.1 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (5.13.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from plotly==5.13.1) (9.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns 
import pandas as pd 
import cufflinks as cf 
from plotly.offline import iplot
import plotly

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import plotly.io as pio
pio.templates.default = "plotly"

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
tips["total_bill"].iplot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 tips["total_bill"].iplot()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\cufflinks\plotlytools.py:839, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     837 	if not isinstance(text,list):
#     838 		text=self[text].values
# --> 839 data=df.to_iplot(colors=colors,colorscale=colorscale,kind=kind,interpolation=interpolation,fill=fill,width=width,dash=dash,sortbars=sortbars,keys=keys,
#     840 		bestfit=bestfit,bestfit_colors=bestfit_colors,mean=mean,mean_colors=mean_colors,asDates=asDates,mode=mode,symbol=symbol,size=size,
#     841 		text=text,**kwargs)
#     842 trace_kw=check_kwargs(kwargs,TRACE_KWARGS)
#     843 for trace in data:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\cufflinks\plotlytools.py:161, in _to_iplot(self, colors, colorscale, kind, mode, interpolation, symbol, size, fill, width, dash, sortbars, keys, bestfit, bestfit_colors, opacity, mean, mean_colors, asDates, asTimestamp, text, **kwargs)
#     159 	lines_plotly=[Bar(lines[key]).to_plotly_json() for key in keys]
#     160 else:
# --> 161 	lines_plotly=[Scatter(lines[key]).to_plotly_json() for key in keys]
#     162 for trace in lines_plotly:
#     163 	if isinstance(trace['name'],pd.Timestamp):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\graph_objs\_scatter.py:3331, in Scatter.__init__(self, arg, alignmentgroup, cliponaxis, connectgaps, customdata, customdatasrc, dx, dy, error_x, error_y, fill, fillcolor, fillpattern, groupnorm, hoverinfo, hoverinfosrc, hoverlabel, hoveron, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, legendgroup, legendgrouptitle, legendrank, legendwidth, line, marker, meta, metasrc, mode, name, offsetgroup, opacity, orientation, selected, selectedpoints, showlegend, stackgaps, stackgroup, stream, text, textfont, textposition, textpositionsrc, textsrc, texttemplate, texttemplatesrc, uid, uirevision, unselected, visible, x, x0, xaxis, xcalendar, xhoverformat, xperiod, xperiod0, xperiodalignment, xsrc, y, y0, yaxis, ycalendar, yhoverformat, yperiod, yperiod0, yperiodalignment, ysrc, **kwargs)
#    3329 _v = line if line is not None else _v
#    3330 if _v is not None:
# -> 3331     self["line"] = _v
#    3332 _v = arg.pop("marker", None)
#    3333 _v = marker if marker is not None else _v
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4843, in BasePlotlyType.__setitem__(self, prop, value)
#    4841 # ### Handle compound property ###
#    4842 if isinstance(validator, CompoundValidator):
# -> 4843     self._set_compound_prop(prop, value)
#    4845 # ### Handle compound array property ###
#    4846 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5254, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5251 # Import value
#    5252 # ------------
#    5253 validator = self._get_validator(prop)
# -> 5254 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5256 # Save deep copies of current and new states
#    5257 # ------------------------------------------
#    5258 curr_val = self._compound_props.get(prop, None)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:2476, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2473     v = self.data_class()
#    2475 elif isinstance(v, dict):
# -> 2476     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2478 elif isinstance(v, self.data_class):
#    2479     # Copy object
#    2480     v = self.data_class(v)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\graph_objs\scatter\_line.py:374, in Line.__init__(self, arg, backoff, backoffsrc, color, dash, shape, simplify, smoothing, width, **kwargs)
#     372 _v = color if color is not None else _v
#     373 if _v is not None:
# --> 374     self["color"] = _v
#     375 _v = arg.pop("dash", None)
#     376 _v = dash if dash is not None else _v
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4851, in BasePlotlyType.__setitem__(self, prop, value)
#    4847         self._set_array_prop(prop, value)
#    4849     # ### Handle simple property ###
#    4850     else:
# -> 4851         self._set_prop(prop, value)
#    4852 else:
#    4853     # Make sure properties dict is initialized
#    4854     self._init_props()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5195, in BasePlotlyType._set_prop(self, prop, val)
#    5193         return
#    5194     else:
# -> 5195         raise err
#    5197 # val is None
#    5198 # -----------
#    5199 if val is None:
#    5200     # Check if we should send null update
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5190, in BasePlotlyType._set_prop(self, prop, val)
#    5187 validator = self._get_validator(prop)
#    5189 try:
# -> 5190     val = validator.validate_coerce(val)
#    5191 except ValueError as err:
#    5192     if self._skip_invalid:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:1375, in ColorValidator.validate_coerce(self, v, should_raise)
#    1373     validated_v = self.vc_scalar(v)
#    1374     if validated_v is None and should_raise:
# -> 1375         self.raise_invalid_val(v)
#    1377     v = validated_v
#    1379 return v
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:288, in BaseValidator.raise_invalid_val(self, v, inds)
#     285             for i in inds:
#     286                 name += "[" + str(i) + "]"
# --> 288         raise ValueError(
#     289             """
#     290     Invalid value of type {typ} received for the '{name}' property of {pname}
#     291         Received value: {v}
#     292
#     293 {valid_clr_desc}""".format(
#     294                 name=name,
#     295                 pname=self.parent_name,
#     296                 typ=type_str(v),
#     297                 v=repr(v),
#     298                 valid_clr_desc=self.description(),
#     299             )
#     300         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'color' property of scatter.line
#         Received value: 'rgba(255, 153, 51, np.float64(1.0))'
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color:
#             aliceblue, antiquewhite, aqua, aquamarine, azure,
#             beige, bisque, black, blanchedalmond, blue,
#             blueviolet, brown, burlywood, cadetblue,
#             chartreuse, chocolate, coral, cornflowerblue,
#             cornsilk, crimson, cyan, darkblue, darkcyan,
#             darkgoldenrod, darkgray, darkgrey, darkgreen,
#             darkkhaki, darkmagenta, darkolivegreen, darkorange,
#             darkorchid, darkred, darksalmon, darkseagreen,
#             darkslateblue, darkslategray, darkslategrey,
#             darkturquoise, darkviolet, deeppink, deepskyblue,
#             dimgray, dimgrey, dodgerblue, firebrick,
#             floralwhite, forestgreen, fuchsia, gainsboro,
#             ghostwhite, gold, goldenrod, gray, grey, green,
#             greenyellow, honeydew, hotpink, indianred, indigo,
#             ivory, khaki, lavender, lavenderblush, lawngreen,
#             lemonchiffon, lightblue, lightcoral, lightcyan,
#             lightgoldenrodyellow, lightgray, lightgrey,
#             lightgreen, lightpink, lightsalmon, lightseagreen,
#             lightskyblue, lightslategray, lightslategrey,
#             lightsteelblue, lightyellow, lime, limegreen,
#             linen, magenta, maroon, mediumaquamarine,
#             mediumblue, mediumorchid, mediumpurple,
#             mediumseagreen, mediumslateblue, mediumspringgreen,
#             mediumturquoise, mediumvioletred, midnightblue,
#             mintcream, mistyrose, moccasin, navajowhite, navy,
#             oldlace, olive, olivedrab, orange, orangered,
#             orchid, palegoldenrod, palegreen, paleturquoise,
#             palevioletred, papayawhip, peachpuff, peru, pink,
#             plum, powderblue, purple, red, rosybrown,
#             royalblue, rebeccapurple, saddlebrown, salmon,
#             sandybrown, seagreen, seashell, sienna, silver,
#             skyblue, slateblue, slategray, slategrey, snow,
#             springgreen, steelblue, tan, teal, thistle, tomato,
#             turquoise, violet, wheat, white, whitesmoke,
#             yellow, yellowgreen

# %%
print(plotly.__version__)
# Out:
# 5.13.1

# %%
import sys
print(sys.version)
# Out:
# 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]

# %%
tips.groupby("day")["tip"].mean().iplot(kind="bar")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_11916\632093594.py:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 tips.groupby("day")["tip"].mean().iplot(kind="bar")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\cufflinks\plotlytools.py:839, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     837 	if not isinstance(text,list):
#     838 		text=self[text].values
# --> 839 data=df.to_iplot(colors=colors,colorscale=colorscale,kind=kind,interpolation=interpolation,fill=fill,width=width,dash=dash,sortbars=sortbars,keys=keys,
#     840 		bestfit=bestfit,bestfit_colors=bestfit_colors,mean=mean,mean_colors=mean_colors,asDates=asDates,mode=mode,symbol=symbol,size=size,
#     841 		text=text,**kwargs)
#     842 trace_kw=check_kwargs(kwargs,TRACE_KWARGS)
#     843 for trace in data:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\cufflinks\plotlytools.py:159, in _to_iplot(self, colors, colorscale, kind, mode, interpolation, symbol, size, fill, width, dash, sortbars, keys, bestfit, bestfit_colors, opacity, mean, mean_colors, asDates, asTimestamp, text, **kwargs)
#     157 			lines[key]["fillcolor"]=to_rgba(colors[key],kwargs['opacity'] if 'opacity' in kwargs else .3		)
#     158 if 'bar' in kind:
# --> 159 	lines_plotly=[Bar(lines[key]).to_plotly_json() for key in keys]
#     160 else:
#     161 	lines_plotly=[Scatter(lines[key]).to_plotly_json() for key in keys]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\graph_objs\_bar.py:3095, in Bar.__init__(self, arg, alignmentgroup, base, basesrc, cliponaxis, constraintext, customdata, customdatasrc, dx, dy, error_x, error_y, hoverinfo, hoverinfosrc, hoverlabel, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, insidetextanchor, insidetextfont, legendgroup, legendgrouptitle, legendrank, legendwidth, marker, meta, metasrc, name, offset, offsetgroup, offsetsrc, opacity, orientation, outsidetextfont, selected, selectedpoints, showlegend, stream, text, textangle, textfont, textposition, textpositionsrc, textsrc, texttemplate, texttemplatesrc, uid, uirevision, unselected, visible, width, widthsrc, x, x0, xaxis, xcalendar, xhoverformat, xperiod, xperiod0, xperiodalignment, xsrc, y, y0, yaxis, ycalendar, yhoverformat, yperiod, yperiod0, yperiodalignment, ysrc, **kwargs)
#    3093 _v = marker if marker is not None else _v
#    3094 if _v is not None:
# -> 3095     self["marker"] = _v
#    3096 _v = arg.pop("meta", None)
#    3097 _v = meta if meta is not None else _v
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4843, in BasePlotlyType.__setitem__(self, prop, value)
#    4841 # ### Handle compound property ###
#    4842 if isinstance(validator, CompoundValidator):
# -> 4843     self._set_compound_prop(prop, value)
#    4845 # ### Handle compound array property ###
#    4846 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5254, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5251 # Import value
#    5252 # ------------
#    5253 validator = self._get_validator(prop)
# -> 5254 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5256 # Save deep copies of current and new states
#    5257 # ------------------------------------------
#    5258 curr_val = self._compound_props.get(prop, None)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:2476, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2473     v = self.data_class()
#    2475 elif isinstance(v, dict):
# -> 2476     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2478 elif isinstance(v, self.data_class):
#    2479     # Copy object
#    2480     v = self.data_class(v)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\graph_objs\bar\_marker.py:1144, in Marker.__init__(self, arg, autocolorscale, cauto, cmax, cmid, cmin, color, coloraxis, colorbar, colorscale, colorsrc, line, opacity, opacitysrc, pattern, reversescale, showscale, **kwargs)
#    1142 _v = line if line is not None else _v
#    1143 if _v is not None:
# -> 1144     self["line"] = _v
#    1145 _v = arg.pop("opacity", None)
#    1146 _v = opacity if opacity is not None else _v
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4843, in BasePlotlyType.__setitem__(self, prop, value)
#    4841 # ### Handle compound property ###
#    4842 if isinstance(validator, CompoundValidator):
# -> 4843     self._set_compound_prop(prop, value)
#    4845 # ### Handle compound array property ###
#    4846 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5254, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5251 # Import value
#    5252 # ------------
#    5253 validator = self._get_validator(prop)
# -> 5254 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5256 # Save deep copies of current and new states
#    5257 # ------------------------------------------
#    5258 curr_val = self._compound_props.get(prop, None)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:2476, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2473     v = self.data_class()
#    2475 elif isinstance(v, dict):
# -> 2476     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2478 elif isinstance(v, self.data_class):
#    2479     # Copy object
#    2480     v = self.data_class(v)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\graph_objs\bar\marker\_line.py:626, in Line.__init__(self, arg, autocolorscale, cauto, cmax, cmid, cmin, color, coloraxis, colorscale, colorsrc, reversescale, width, widthsrc, **kwargs)
#     624 _v = color if color is not None else _v
#     625 if _v is not None:
# --> 626     self["color"] = _v
#     627 _v = arg.pop("coloraxis", None)
#     628 _v = coloraxis if coloraxis is not None else _v
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4851, in BasePlotlyType.__setitem__(self, prop, value)
#    4847         self._set_array_prop(prop, value)
#    4849     # ### Handle simple property ###
#    4850     else:
# -> 4851         self._set_prop(prop, value)
#    4852 else:
#    4853     # Make sure properties dict is initialized
#    4854     self._init_props()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5195, in BasePlotlyType._set_prop(self, prop, val)
#    5193         return
#    5194     else:
# -> 5195         raise err
#    5197 # val is None
#    5198 # -----------
#    5199 if val is None:
#    5200     # Check if we should send null update
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5190, in BasePlotlyType._set_prop(self, prop, val)
#    5187 validator = self._get_validator(prop)
#    5189 try:
# -> 5190     val = validator.validate_coerce(val)
#    5191 except ValueError as err:
#    5192     if self._skip_invalid:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:1375, in ColorValidator.validate_coerce(self, v, should_raise)
#    1373     validated_v = self.vc_scalar(v)
#    1374     if validated_v is None and should_raise:
# -> 1375         self.raise_invalid_val(v)
#    1377     v = validated_v
#    1379 return v
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:288, in BaseValidator.raise_invalid_val(self, v, inds)
#     285             for i in inds:
#     286                 name += "[" + str(i) + "]"
# --> 288         raise ValueError(
#     289             """
#     290     Invalid value of type {typ} received for the '{name}' property of {pname}
#     291         Received value: {v}
#     292
#     293 {valid_clr_desc}""".format(
#     294                 name=name,
#     295                 pname=self.parent_name,
#     296                 typ=type_str(v),
#     297                 v=repr(v),
#     298                 valid_clr_desc=self.description(),
#     299             )
#     300         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'color' property of bar.marker.line
#         Received value: 'rgba(255, 153, 51, np.float64(1.0))'
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color:
#             aliceblue, antiquewhite, aqua, aquamarine, azure,
#             beige, bisque, black, blanchedalmond, blue,
#             blueviolet, brown, burlywood, cadetblue,
#             chartreuse, chocolate, coral, cornflowerblue,
#             cornsilk, crimson, cyan, darkblue, darkcyan,
#             darkgoldenrod, darkgray, darkgrey, darkgreen,
#             darkkhaki, darkmagenta, darkolivegreen, darkorange,
#             darkorchid, darkred, darksalmon, darkseagreen,
#             darkslateblue, darkslategray, darkslategrey,
#             darkturquoise, darkviolet, deeppink, deepskyblue,
#             dimgray, dimgrey, dodgerblue, firebrick,
#             floralwhite, forestgreen, fuchsia, gainsboro,
#             ghostwhite, gold, goldenrod, gray, grey, green,
#             greenyellow, honeydew, hotpink, indianred, indigo,
#             ivory, khaki, lavender, lavenderblush, lawngreen,
#             lemonchiffon, lightblue, lightcoral, lightcyan,
#             lightgoldenrodyellow, lightgray, lightgrey,
#             lightgreen, lightpink, lightsalmon, lightseagreen,
#             lightskyblue, lightslategray, lightslategrey,
#             lightsteelblue, lightyellow, lime, limegreen,
#             linen, magenta, maroon, mediumaquamarine,
#             mediumblue, mediumorchid, mediumpurple,
#             mediumseagreen, mediumslateblue, mediumspringgreen,
#             mediumturquoise, mediumvioletred, midnightblue,
#             mintcream, mistyrose, moccasin, navajowhite, navy,
#             oldlace, olive, olivedrab, orange, orangered,
#             orchid, palegoldenrod, palegreen, paleturquoise,
#             palevioletred, papayawhip, peachpuff, peru, pink,
#             plum, powderblue, purple, red, rosybrown,
#             royalblue, rebeccapurple, saddlebrown, salmon,
#             sandybrown, seagreen, seashell, sienna, silver,
#             skyblue, slateblue, slategray, slategrey, snow,
#             springgreen, steelblue, tan, teal, thistle, tomato,
#             turquoise, violet, wheat, white, whitesmoke,
#             yellow, yellowgreen
#       - A number that will be interpreted as a color
#         according to bar.marker.line.colorscale
#       - A list or array of any of the above

# %%
tips.iplot(kind="scatter", x="total_bill", y="tip", mod="markers")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 tips.iplot(kind="scatter", x="total_bill", y="tip", mod="markers")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\cufflinks\plotlytools.py:696, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     694 for key in list(kwargs.keys()):
#     695 	if key not in valid_kwargs:
# --> 696 		raise Exception("Invalid keyword : '{0}'".format(key))
#     698 # Setting default values
#     699 if not colors:
#
# Exception: Invalid keyword : 'mod'

# %%
tips[["total_bill", "day"]].iplot(kind="box", x="total_bill", y="day")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 tips[["total_bill", "day"]].iplot(kind="box", x="total_bill", y="day")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\cufflinks\plotlytools.py:911, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     909 for _ in columns:
#     910 	if kind=='box':
# --> 911 		__=Box(y=df[_].values.tolist(),marker=dict(color=clrs[_]),name=_,
#     912 				line=dict(width=width),boxpoints=boxpoints)
#     913 		# 114 - Horizontal Box
#     914 		__['orientation']=orientation
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\graph_objs\_box.py:3209, in Box.__init__(self, arg, alignmentgroup, boxmean, boxpoints, customdata, customdatasrc, dx, dy, fillcolor, hoverinfo, hoverinfosrc, hoverlabel, hoveron, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, jitter, legendgroup, legendgrouptitle, legendrank, legendwidth, line, lowerfence, lowerfencesrc, marker, mean, meansrc, median, mediansrc, meta, metasrc, name, notched, notchspan, notchspansrc, notchwidth, offsetgroup, opacity, orientation, pointpos, q1, q1src, q3, q3src, quartilemethod, sd, sdsrc, selected, selectedpoints, showlegend, stream, text, textsrc, uid, uirevision, unselected, upperfence, upperfencesrc, visible, whiskerwidth, width, x, x0, xaxis, xcalendar, xhoverformat, xperiod, xperiod0, xperiodalignment, xsrc, y, y0, yaxis, ycalendar, yhoverformat, yperiod, yperiod0, yperiodalignment, ysrc, **kwargs)
#    3207 _v = marker if marker is not None else _v
#    3208 if _v is not None:
# -> 3209     self["marker"] = _v
#    3210 _v = arg.pop("mean", None)
#    3211 _v = mean if mean is not None else _v
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4843, in BasePlotlyType.__setitem__(self, prop, value)
#    4841 # ### Handle compound property ###
#    4842 if isinstance(validator, CompoundValidator):
# -> 4843     self._set_compound_prop(prop, value)
#    4845 # ### Handle compound array property ###
#    4846 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5254, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5251 # Import value
#    5252 # ------------
#    5253 validator = self._get_validator(prop)
# -> 5254 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5256 # Save deep copies of current and new states
#    5257 # ------------------------------------------
#    5258 curr_val = self._compound_props.get(prop, None)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:2476, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2473     v = self.data_class()
#    2475 elif isinstance(v, dict):
# -> 2476     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2478 elif isinstance(v, self.data_class):
#    2479     # Copy object
#    2480     v = self.data_class(v)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\graph_objs\box\_marker.py:470, in Marker.__init__(self, arg, angle, color, line, opacity, outliercolor, size, symbol, **kwargs)
#     468 _v = color if color is not None else _v
#     469 if _v is not None:
# --> 470     self["color"] = _v
#     471 _v = arg.pop("line", None)
#     472 _v = line if line is not None else _v
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4851, in BasePlotlyType.__setitem__(self, prop, value)
#    4847         self._set_array_prop(prop, value)
#    4849     # ### Handle simple property ###
#    4850     else:
# -> 4851         self._set_prop(prop, value)
#    4852 else:
#    4853     # Make sure properties dict is initialized
#    4854     self._init_props()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5195, in BasePlotlyType._set_prop(self, prop, val)
#    5193         return
#    5194     else:
# -> 5195         raise err
#    5197 # val is None
#    5198 # -----------
#    5199 if val is None:
#    5200     # Check if we should send null update
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5190, in BasePlotlyType._set_prop(self, prop, val)
#    5187 validator = self._get_validator(prop)
#    5189 try:
# -> 5190     val = validator.validate_coerce(val)
#    5191 except ValueError as err:
#    5192     if self._skip_invalid:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:1375, in ColorValidator.validate_coerce(self, v, should_raise)
#    1373     validated_v = self.vc_scalar(v)
#    1374     if validated_v is None and should_raise:
# -> 1375         self.raise_invalid_val(v)
#    1377     v = validated_v
#    1379 return v
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:288, in BaseValidator.raise_invalid_val(self, v, inds)
#     285             for i in inds:
#     286                 name += "[" + str(i) + "]"
# --> 288         raise ValueError(
#     289             """
#     290     Invalid value of type {typ} received for the '{name}' property of {pname}
#     291         Received value: {v}
#     292
#     293 {valid_clr_desc}""".format(
#     294                 name=name,
#     295                 pname=self.parent_name,
#     296                 typ=type_str(v),
#     297                 v=repr(v),
#     298                 valid_clr_desc=self.description(),
#     299             )
#     300         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'color' property of box.marker
#         Received value: 'rgba(255, 153, 51, np.float64(1.0))'
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color:
#             aliceblue, antiquewhite, aqua, aquamarine, azure,
#             beige, bisque, black, blanchedalmond, blue,
#             blueviolet, brown, burlywood, cadetblue,
#             chartreuse, chocolate, coral, cornflowerblue,
#             cornsilk, crimson, cyan, darkblue, darkcyan,
#             darkgoldenrod, darkgray, darkgrey, darkgreen,
#             darkkhaki, darkmagenta, darkolivegreen, darkorange,
#             darkorchid, darkred, darksalmon, darkseagreen,
#             darkslateblue, darkslategray, darkslategrey,
#             darkturquoise, darkviolet, deeppink, deepskyblue,
#             dimgray, dimgrey, dodgerblue, firebrick,
#             floralwhite, forestgreen, fuchsia, gainsboro,
#             ghostwhite, gold, goldenrod, gray, grey, green,
#             greenyellow, honeydew, hotpink, indianred, indigo,
#             ivory, khaki, lavender, lavenderblush, lawngreen,
#             lemonchiffon, lightblue, lightcoral, lightcyan,
#             lightgoldenrodyellow, lightgray, lightgrey,
#             lightgreen, lightpink, lightsalmon, lightseagreen,
#             lightskyblue, lightslategray, lightslategrey,
#             lightsteelblue, lightyellow, lime, limegreen,
#             linen, magenta, maroon, mediumaquamarine,
#             mediumblue, mediumorchid, mediumpurple,
#             mediumseagreen, mediumslateblue, mediumspringgreen,
#             mediumturquoise, mediumvioletred, midnightblue,
#             mintcream, mistyrose, moccasin, navajowhite, navy,
#             oldlace, olive, olivedrab, orange, orangered,
#             orchid, palegoldenrod, palegreen, paleturquoise,
#             palevioletred, papayawhip, peachpuff, peru, pink,
#             plum, powderblue, purple, red, rosybrown,
#             royalblue, rebeccapurple, saddlebrown, salmon,
#             sandybrown, seagreen, seashell, sienna, silver,
#             skyblue, slateblue, slategray, slategrey, snow,
#             springgreen, steelblue, tan, teal, thistle, tomato,
#             turquoise, violet, wheat, white, whitesmoke,
#             yellow, yellowgreen
